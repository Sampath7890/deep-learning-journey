# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
from sklearn.linear_model import Perceptron

# %%
df = pd.read_csv(r"C:\Users\gsksd\Downloads\placement (3).csv")

# %%
df.sample(5)
# Out:
#     cgpa  resume_score  placed
# 8   6.32          6.71       0
# 61  6.89          7.96       1
# 21  6.53          7.64       0
# 16  8.04          7.64       1
# 40  8.25          5.32       1

# %%
sns.scatterplot(
    x=df['cgpa'],
    y=df['resume_score'],
    hue=df['placed']
)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %% [markdown]
# ## Perceptron training

# %%
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])
